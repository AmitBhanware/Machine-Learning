# %%
# !pip install numpy
# Out:
# mambajs 0.19.13
#
# Process pip requirements ...
#
# Requirement numpy already handled by conda/micromamba/mamba.

# %%
# !pip install seaborn
# Out:
# mambajs 0.19.13
#
# Process pip requirements ...
#
# Requirement seaborn already handled by conda/micromamba/mamba.

# %%
# !pip install matplotlib
# Out:
# mambajs 0.19.13
#
# Process pip requirements ...
#
# Requirement matplotlib already handled by conda/micromamba/mamba.

# %%
# !mamba install pandas
# Out:
# mambajs 0.19.13
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas, seaborn
# Channels: emscripten-forge, conda-forge
#
# Solving environment...
# Solving took 13.45719999998808 seconds
# All requested packages already installed.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
# !mamba install seaborn
# Out:
# mambajs 0.19.13
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas, seaborn
# Channels: emscripten-forge, conda-forge
#
# Solving environment...
# Solving took 12.69630000001192 seconds
# All requested packages already installed.

# %%
import seaborn as sns

# %%
df = pd.read_csv('Advertising.csv')

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df['total_spend'] = df['TV'] + df['radio'] + df['newspaper']

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales  total_spend
# 0  230.1   37.8       69.2   22.1        337.1
# 1   44.5   39.3       45.1   10.4        128.9
# 2   17.2   45.9       69.3    9.3        132.4
# 3  151.5   41.3       58.5   18.5        251.3
# 4  180.8   10.8       58.4   12.9        250.0

# %%
sns.regplot(data= df, x = 'total_spend', y = 'sales')
# Out:
# <Axes: xlabel='total_spend', ylabel='sales'>

# %%
X = df['total_spend']
y = df['sales']

# %%
#y = mx +c
#y = B1x + B2
#help(np.polyfit)

# %%
b1, b2 = np.polyfit(X, y, deg =1)

# %%
potential_spend = np.linspace(0,500,100)

# %%
predicted_sales = 0.04868788* potential_spend + 4.24302822

# %%
sns.scatterplot(data= df, x = 'total_spend', y = 'sales')
plt.plot(potential_spend, predicted_sales, color = 'red')

# %%
spend = 200
predicted_sales = 0.04868788* spend + 4.24302822

# %%
predicted_sales
# Out:
# 13.98060422

# %%
np.polyfit(X, y, deg =3)
# Out:
# array([ 3.07615033e-07, -1.89392449e-04,  8.20886302e-02,  2.70495053e+00])

# %%
pot_spend = np.linspace(0,500,100)

# %%
pre_sale = 3.07615033e-07*pot_spend**3 + -1.89392449e-04*pot_spend**2  + 8.20886302e-02*pot_spend + 2.70495053e+00

# %%
sns.scatterplot(data= df, x = 'total_spend', y = 'sales')
plt.plot(pot_spend, pre_sale, color = 'red')
