# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv('Advertising.csv')

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
X = df.drop('sales', axis = 1)

# %%
y = df['sales']

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
polynomial_converter = PolynomialFeatures(degree = 2, include_bias = False)

# %%
polynomial_converter.fit(X)
# Out:
# PolynomialFeatures(include_bias=False)

# %%
polynomial_converter.transform(X)
# Out:
# array([[ 230.1 ,   37.8 ,   69.2 , ..., 1428.84, 2615.76, 4788.64],
#        [  44.5 ,   39.3 ,   45.1 , ..., 1544.49, 1772.43, 2034.01],
#        [  17.2 ,   45.9 ,   69.3 , ..., 2106.81, 3180.87, 4802.49],
#        ...,
#        [ 177.  ,    9.3 ,    6.4 , ...,   86.49,   59.52,   40.96],
#        [ 283.6 ,   42.  ,   66.2 , ..., 1764.  , 2780.4 , 4382.44],
#        [ 232.1 ,    8.6 ,    8.7 , ...,   73.96,   74.82,   75.69]])

# %%
poly_features =polynomial_converter.fit_transform(X)

# %%
poly_features[0]
# Out:
# array([2.301000e+02, 3.780000e+01, 6.920000e+01, 5.294601e+04,
#        8.697780e+03, 1.592292e+04, 1.428840e+03, 2.615760e+03,
#        4.788640e+03])

# %%
poly_features[0][:3]
# Out:
# array([230.1,  37.8,  69.2])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(poly_features, y, test_size = 0.3, random_state = 101)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
test_predictions = model.predict(X_test)

# %%
model.coef_
# Out:
# array([ 5.17095811e-02,  1.30848864e-02,  1.20000085e-02, -1.10892474e-04,
#         1.14212673e-03, -5.24100082e-05,  3.34919737e-05,  1.46380310e-04,
#        -3.04715806e-05])

# %%
poly_features[0]
# Out:
# array([2.301000e+02, 3.780000e+01, 6.920000e+01, 5.294601e+04,
#        8.697780e+03, 1.592292e+04, 1.428840e+03, 2.615760e+03,
#        4.788640e+03])

# %% [markdown]
# Ridge(L2) Regularization

# %%
from sklearn.linear_model import Ridge

# %%
ridge_model = Ridge(alpha = 10)

# %%
ridge_model.fit(X_train, y_train)
# Out:
# Ridge(alpha=10)

# %%
test_predictions = ridge_model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
MAE = mean_absolute_error(y_test, test_predictions)

# %%
MAE
# Out:
# 0.48964179818294795

# %%
RMSE = np.sqrt(mean_squared_error(y_test, test_predictions))

# %%
RMSE
# Out:
# np.float64(0.6646503354139192)

# %%
from sklearn.linear_model import RidgeCV

# %%
ridge_cv_model = RidgeCV(alphas= (0.1, 1.0, 10.0), scoring = 'neg_mean_absolute_error')

# %%
ridge_cv_model.fit(X_train, y_train)
# Out:
# RidgeCV(scoring='neg_mean_absolute_error')

# %%
ridge_cv_model.alpha_
# Out:
# np.float64(10.0)

# %%
from sklearn.metrics import get_scorer_names

# To see the available scorers:
# print(get_scorer_names())

# %%
get_scorer_names
# Out:
# <function sklearn.metrics._scorer.get_scorer_names()>

# %%
test_predictions = ridge_cv_model.predict(X_test)

# %%
MAE = mean_absolute_error(y_test, test_predictions)

# %%
RMSE = np.sqrt(mean_squared_error(y_test, test_predictions))

# %%
MAE
# Out:
# 0.4896419415414565

# %%
RMSE
# Out:
# np.float64(0.6646506280444593)

# %%
ridge_cv_model.coef_
# Out:
# array([ 5.17010794e-02,  1.30078679e-02,  1.19698970e-02, -1.10875162e-04,
#         1.14221550e-03, -5.23753500e-05,  3.45356168e-05,  1.46748456e-04,
#        -3.03304244e-05])

# %%
ridge_cv_model.
# Out:
# <function sklearn.utils._metadata_requests.RequestMethod.__get__.<locals>.func(self: sklearn.linear_model._ridge.RidgeCV, *, sample_weight: Union[bool, NoneType, str] = '$UNCHANGED$') -> sklearn.linear_model._ridge.RidgeCV>

# %% [markdown]
# LASSO (L1) regularization (Least absolute shrinkage and selection operator)

# %%
from sklearn.linear_model import LassoCV

# %%
lasso_cv_model = LassoCV(eps = 0.1, n_alphas = 1000, cv = 5)

# %%
lasso_cv_model.fit(X_train, y_train)
# Out:
# LassoCV(cv=5, eps=0.1, n_alphas=1000)

# %%
lasso_cv_model.alpha_
# Out:
# np.float64(9331.637903102042)

# %%
test_predictions = lasso_cv_model.predict(X_test)

# %%
MAE = mean_absolute_error(y_test, test_predictions)

# %%
RMSE = np.sqrt(mean_squared_error(y_test, test_predictions))

# %%
lasso_cv_model.coef_
# Out:
# array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.28232569e-04,
#        1.91250496e-05, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00])

# %%
from sklearn.linear_model import ElasticNetCV

# %%
elastic_model = ElasticNetCV(l1_ratio =[.1, .5, .7, .9, .95, .99, 1], eps = 0.001, n_alphas = 100, max_iter = 1000000)

# %%
elastic_model.fit(X_train, y_train)
# Out:
# ElasticNetCV(l1_ratio=[0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1], max_iter=1000000)

# %%
elastic_model.l1_ratio_
# Out:
# np.float64(1.0)

# %%
elastic_model.alpha_
# Out:
# np.float64(163.0730225425898)

# %%
test_predictions = elastic_model.predict(X_test)

# %%
MAE = mean_absolute_error(y_test, test_predictions)

# %%
RMSE = np.sqrt(mean_squared_error(y_test, test_predictions))

# %%
MAE
# Out:
# 0.8095871425145572

# %%
RMSE
# Out:
# np.float64(1.2151556695813133)
